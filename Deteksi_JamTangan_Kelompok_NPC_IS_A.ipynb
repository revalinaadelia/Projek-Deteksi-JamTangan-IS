# %% [markdown]
# <a href="https://colab.research.google.com/github/revalinaadelia/Projek-Deteksi-JamTangan-IS/blob/main/Deteksi_JamTangan_Kelompok_NPC_IS_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.3 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train model=yolo11n.pt data="/content/drive/MyDrive/Deteksi-Jam-Tangan/Deteksi-Jam-Tangan-YoloV11/data.yaml"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp "/content/runs/detect/train/weights/best.pt" "/content/drive/MyDrive/Deteksi-Jam-Tangan/"

# %%
# !ls "/content/drive/MyDrive/Deteksi-Jam-Tangan"
# Out:
# best.pt  Deteksi-Jam-Tangan-YoloV11

# %%
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/Deteksi-Jam-Tangan/best.pt")

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/Deteksi-Jam-Tangan/best.pt")

results = model.predict(
    source="/content/drive/MyDrive/Dataset-Jam-Tangan/Hitam/Jam Tangan Hitam 1.png",
    save=True
)
# Out:
# image 1/1 /content/drive/MyDrive/Dataset-Jam-Tangan/Hitam/Jam Tangan Hitam 1.png: 640x640 1 Jam Tangan Hitam, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict2

# %%
# !ls /content/runs/detect/predict
# Out:
# 'Jam Tangan Hitam 1.jpg'
